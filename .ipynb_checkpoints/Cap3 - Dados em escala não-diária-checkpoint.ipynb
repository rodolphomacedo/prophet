# %%
import pandas as pd
import matplotlib.pyplot as plt
from prophet import Prophet

# %% [markdown]
# Iremos ver nessa parte:
#
#     - Usando dados mensais
#     - Usando dados intra-diários
#     - Usando dados com Gap regulares

# %%
df = pd.read_csv('./data/AirPassengers.csv')
df['Month'] = pd.to_datetime(df['Month'])
df.columns = ['ds', 'y']
df.head()
# Out:
#           ds    y
# 0 1949-01-01  112
# 1 1949-02-01  118
# 2 1949-03-01  132
# 3 1949-04-01  129
# 4 1949-05-01  121

# %%
model = Prophet(seasonality_mode='multiplicative')
model.fit(df)
# Out:
# 17:59:33 - cmdstanpy - INFO - Chain [1] start processing
# 17:59:33 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = model.make_future_dataframe(periods=365*5)
forecast = model.predict(future)
fig = model.plot(forecast, xlabel='Date', ylabel=r'y data')
plt.title('Air Passagenrs - Errado - Dados Futuros não dários')
plt.show()

# %% [markdown]
# Os dados são mensais, os dados futuros são diários.

# %%
forecast.ds.tail()
# Out:
# 1964   1965-11-26
# 1965   1965-11-27
# 1966   1965-11-28
# 1967   1965-11-29
# 1968   1965-11-30
# Name: ds, dtype: datetime64[ns]

# %%
future = model.make_future_dataframe(periods=12*5, freq='MS')
forecast = model.predict(future)
fig = model.plot(forecast, xlabel='Date', ylabel=r'y data')
plt.title('Air Passagenrs - Certo - Dados Mensais')
plt.show()

# %% [markdown]
# # Dados Sub-diários

# %%
df = pd.read_csv('./data/divvy_hourly.csv')
df['date'] = pd.to_datetime(df['date'])
df.columns = ['ds', 'y']
df.head()
# Out:
#                    ds  y
# 0 2014-01-01 01:00:00  1
# 1 2014-01-01 02:00:00  9
# 2 2014-01-01 03:00:00  4
# 3 2014-01-01 04:00:00  1
# 4 2014-01-01 07:00:00  2

# %%
model = Prophet(seasonality_mode='multiplicative')
model.fit(df)

future = model.make_future_dataframe(
    periods=365 * 24,
    freq='h'
)
# Out:
# 18:23:40 - cmdstanpy - INFO - Chain [1] start processing
# 18:24:05 - cmdstanpy - INFO - Chain [1] done processing

# %%
forecast = model.predict(future)
fig = model.plot(forecast)

plt.show()

fig2 = model.plot_components(forecast)
plt.show()

# %% [markdown]
# ## Dados com gaps regulares

# %%
df = df[(df['ds'].dt.hour >= 8) & (df['ds'].dt.hour < 18)]

# %%
plt.plot(df['y'], 'o', ms=1)
plt.show()

# %%
model = Prophet(seasonality_mode='multiplicative')
model.fit(df)
future = model.make_future_dataframe(periods=365*24, freq='h')

forecast = model.predict(future)
fig = model.plot(forecast)
plt.show()
# Out:
# 18:38:21 - cmdstanpy - INFO - Chain [1] start processing
# 18:38:45 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# Esse é o mesmo problema anterior, estamos fazendo a predição para dias que não temos a estimativa do Prophet.

# %%
fig = model.plot(forecast)
plt.xlim(pd.to_datetime(['2018-08-01', '2018-08-04']))
plt.ylim(-2000, 4000)
plt.show()

# %% [markdown]
# Construindo a estimativa apenas no período entre $8$ e $18$

# %%
future2 = future[(future['ds'].dt.hour >= 8) & (future['ds'].dt.hour < 18)]
forecast2 = model.predict(future2)
fig = model.plot(forecast2)
plt.show()

# %%
fig = model.plot(forecast2)
plt.xlim(pd.to_datetime(['2018-08-01',  '2018-08-04']))
plt.ylim(-2000, 4000)
plt.show()

# %% [markdown]
# Perceba que não existe previsão para horários que não temos estimativas.

# %%
model.plot_components(forecast2)
plt.show()
