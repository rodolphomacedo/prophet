# %% [markdown]
# # Sazonalidade
#
# O coração do $prophet$.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from prophet import Prophet
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
df = pd.read_csv('./data/AirPassengers.csv')
df['Month'] = pd.to_datetime(df['Month'])
df.columns = ['ds', 'y']
df.head()
# Out:
#           ds    y
# 0 1949-01-01  112
# 1 1949-02-01  118
# 2 1949-03-01  132
# 3 1949-04-01  129
# 4 1949-05-01  121

# %%
model_a = Prophet(seasonality_mode='additive', yearly_seasonality=4)
model_a.fit(df)
forecast_a = model_a.predict()
fig_a = model_a.plot(forecast_a)
plt.show()
# Out:
# 20:20:40 - cmdstanpy - INFO - Chain [1] start processing
# 20:20:40 - cmdstanpy - INFO - Chain [1] done processing

# %%
model_m = Prophet(seasonality_mode='multiplicative', yearly_seasonality=4)
model_m.fit(df)
forecast_m = model_m.predict()
fig_m = model_m.plot(forecast_m)
plt.show()
# Out:
# 20:20:41 - cmdstanpy - INFO - Chain [1] start processing
# 20:20:41 - cmdstanpy - INFO - Chain [1] done processing

# %%
forecast_m.head(3).T
# Out:
#                                               0                    1  \
# ds                          1949-01-01 00:00:00  1949-02-01 00:00:00
# trend                                111.737324           113.687588
# yhat_lower                            86.233459            85.063522
# yhat_upper                           115.697578           116.147569
# trend_lower                          111.737324           113.687588
# trend_upper                          111.737324           113.687588
# multiplicative_terms                  -0.101204             -0.11911
# multiplicative_terms_lower            -0.101204             -0.11911
# multiplicative_terms_upper            -0.101204             -0.11911
# yearly                                -0.101204             -0.11911
# yearly_lower                          -0.101204             -0.11911
# yearly_upper                          -0.101204             -0.11911
# additive_terms                              0.0                  0.0
# additive_terms_lower                        0.0                  0.0
# additive_terms_upper                        0.0                  0.0
# yhat                                 100.429061           100.146288
#
#                                               2
# ds                          1949-03-01 00:00:00
# trend                                115.449118
# yhat_lower                            94.936294
# yhat_upper                           127.363358
# trend_lower                          115.449118
# trend_upper                          115.449118
# multiplicative_terms                  -0.043247
# multiplicative_terms_lower            -0.043247
# multiplicative_terms_upper            -0.043247
# yearly                                -0.043247
# yearly_lower                          -0.043247
# yearly_upper                          -0.043247
# additive_terms                              0.0
# additive_terms_lower                        0.0
# additive_terms_upper                        0.0
# yhat                                 110.456232

# %%
fig2_a2 = model_a.plot_components(forecast_a)
plt.show()

# %%
fig2_m = model_m.plot_components(forecast_m)
plt.show()

# %% [markdown]
# ### Pag 68 - Dicas
#
# Quando os dados representam uma contagem de dados no tempo, como a quantidade de passageiros, nós iremos geralmente usar a `sazonalidade multiplicativa`. Usar a sazonalidade aditiva, poderá causar valores preditos negativos.

# %%
df = pd.read_csv('./data/divvy_daily.csv')
df.head()
# Out:
#        date  rides  temperature       weather
# 0  1/1/2014     95    19.483158  rain or snow
# 1  1/2/2014    111    16.833333  rain or snow
# 2  1/3/2014      6    -5.633333         clear
# 3  1/4/2014    181    30.007735  rain or snow
# 4  1/5/2014     32    16.756250  rain or snow

# %% [markdown]
# Vamos usar o dados de temperatura e tempo no capítulo 8

# %%
df = pd.read_csv('./data/divvy_daily.csv')
df = df[['date', 'rides']]
df['date'] = pd.to_datetime(df['date'])
df.columns = ['ds', 'y']
df.head()
# Out:
#           ds    y
# 0 2014-01-01   95
# 1 2014-01-02  111
# 2 2014-01-03    6
# 3 2014-01-04  181
# 4 2014-01-05   32

# %%
model = Prophet(seasonality_mode = 'multiplicative', yearly_seasonality='auto')
model.fit(df)

future = model.make_future_dataframe(periods=365)
forecast = model.predict(future)
fig = model.plot(forecast)
plt.show()
# Out:
# 20:57:12 - cmdstanpy - INFO - Chain [1] start processing
# 20:57:12 - cmdstanpy - INFO - Chain [1] done processing

# %%
fig2 = model.plot_components(forecast)
plt.show()

# %% [markdown]
# ### Controlando a sazonalidade com as ordens da série de Fourier

# %% [markdown]
# continuar da página 76...
